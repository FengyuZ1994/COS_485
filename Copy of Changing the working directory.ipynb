# %%
# !pwd
# Out:
# /content

# %%
# !mkdir -p abc
# !echo "file" > abc/123.txt
# !ls
# Out:
# abc  datalab

# %%
import os
os.chdir('abc')

# Now the directory 'abc' is the current working directory.
# !ls
# Out:
# 123.txt
